# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from matplotlib.animation import FuncAnimation
from PIL import Image

# %%
class grid():
    def __init__ (self, CFL):
    
        self.L = 20
        self.T = 18
        self.h = 0.5
        self.CFL = CFL
        self.tau = self.h * CFL
        self.xr = np.arange(0, (self.L + self.h/2) , self.h)
        self.tr = np.arange(0, (self.T + self.tau/2), self.tau)
        self.a = min(self.xr)
        self.b = max(self.xr)
        self.N = len(self.tr)
        self.M = len(self.xr)

# %%
const = 0.1
phi1 = lambda t: const
phi2 = lambda t: 2*const
psi1 = lambda t: const
psi2 = lambda t: 2*const

# %%
grid_06 = grid(0.6)

# %%
u0 = lambda grid, x: np.sin(np.pi * x / grid.L)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
a = 2
alpha1 = lambda grid, i: 1/(1+grid.h*phi1(grid.T[i]))
beta1 = lambda grid, i: -grid.h * psi1(grid.T[i])/(1+grid.h*phi1(grid.T[i]))

# %%
def TMA(grid):
    u = np.zeros([grid.N, grid.M])
#     u[0] = [u0(n) for n in range(grid.M)]
    u[0] = [u0(grid, x) for x in grid.xr]
    for i in range(grid.N - 1):
        al1 = alpha1(grid, i)
        bt1 = beta1(grid, i)
        for j in range(1, grid.M-1):
            u[i+1][j] = Y(grid, u[i][j-1], u[i][j], u[i][j+1])
        u[i+1][grid.M-1] = Y(grid, u[i][grid.M-2], u[i][grid.M-1], u[i][0])
        
    return u
